# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np

# %%
df=pd.read_csv("kc_house_data (1).csv")
df
# Out:
#                id             date     price  bedrooms  bathrooms  \
# 0      7129300520  20141013T000000  221900.0         3       1.00
# 1      6414100192  20141209T000000  538000.0         3       2.25
# 2      5631500400  20150225T000000  180000.0         2       1.00
# 3      2487200875  20141209T000000  604000.0         4       3.00
# 4      1954400510  20150218T000000  510000.0         3       2.00
# ...           ...              ...       ...       ...        ...
# 21608   263000018  20140521T000000  360000.0         3       2.50
# 21609  6600060120  20150223T000000  400000.0         4       2.50
# 21610  1523300141  20140623T000000  402101.0         2       0.75
# 21611   291310100  20150116T000000  400000.0         3       2.50
# 21612  1523300157  20141015T000000  325000.0         2       0.75
#
#        sqft_living  sqft_lot  floors  waterfront  view  ...  grade  \
# 0             1180      5650     1.0           0     0  ...      7
# ...

# %%
plt.figure(figsize=(10,6))
sns.regplot(data=df,x="sqft_living",y="price")
plt.title("sqft living vs price")
plt.xlabel("sqft living")
plt.ylabel("price")
plt.show()

# %%
plt.figure(figsize=(10,6))
sns.scatterplot(
    data=df,
    x="lat",
    y="long"
)
plt.title("lattitude vs longitude")
plt.xlabel("lattitude")
plt.ylabel("longitude")
plt.legend=False
plt.palette="red"
plt.show()

# %%
locate_summary=df.groupby("zipcode")["price"].agg(
    ["count", "mean", "median", "max"]
).reset_index()
locate_summary=locate_summary.sort_values(
by="mean",
ascending=False
)
locate_summary.head(10)
# Out:
#     zipcode  count          mean     median        max
# 24    98039     50  2.160607e+06  1892500.0  6885000.0
# 3     98004    317  1.355927e+06  1150000.0  7062500.0
# 25    98040    282  1.194230e+06   993750.0  5300000.0
# 48    98112    269  1.095499e+06   915000.0  3400000.0
# 41    98102    105  9.012583e+05   720000.0  7700000.0
# 47    98109    109  8.796236e+05   736000.0  3200000.0
# 43    98105    229  8.628252e+05   675000.0  3650000.0
# 5     98006    498  8.596848e+05   760184.5  4208000.0
# 53    98119    184  8.494480e+05   744975.0  3065000.0
# 4     98005    168  8.101649e+05   765475.0  1960000.0

# %%
plt.figure(figsize=(10,6))
sns.boxplot(data=df,x="waterfront",y="price")
plt.title("waterfront vs price")
plt.xlabel("waterfront")
plt.ylabel("price")
plt.show()

# %%
plt.figure(figsize=(10,6))
sns.scatterplot(
    data=df,
    x="lat",
    y="long"
)
plt.title("lattitude vs longitude")
plt.xlabel("lattitude")
plt.ylabel("longitude")
plt.legend=False
plt.palette="red"
plt.show()

# %%
location_summary = df.groupby("zipcode")["price"].agg(
    ["count","mean","median","max"]
).reset_index()

loction_summary = location_summary.sort_values(
    by="mean",
    ascending=False
)
loction_summary.head(10)
# Out:
#     zipcode  count          mean     median        max
# 24    98039     50  2.160607e+06  1892500.0  6885000.0
# 3     98004    317  1.355927e+06  1150000.0  7062500.0
# 25    98040    282  1.194230e+06   993750.0  5300000.0
# 48    98112    269  1.095499e+06   915000.0  3400000.0
# 41    98102    105  9.012583e+05   720000.0  7700000.0
# 47    98109    109  8.796236e+05   736000.0  3200000.0
# 43    98105    229  8.628252e+05   675000.0  3650000.0
# 5     98006    498  8.596848e+05   760184.5  4208000.0
# 53    98119    184  8.494480e+05   744975.0  3065000.0
# 4     98005    168  8.101649e+05   765475.0  1960000.0
